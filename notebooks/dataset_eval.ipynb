# %%
from datasets import load_dataset

# %%
quati_1M = load_dataset("unicamp-dl/quati", trust_remote_code=True)
quati_1M_qrels = load_dataset("unicamp-dl/quati", "quati_1M_qrels", trust_remote_code=True)
quati_all_topics = load_dataset("unicamp-dl/quati", "quati_all_topics", trust_remote_code=True)
# Out:
# Downloading readme: 0.00B [00:00, ?B/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Generating quati_1M_qrels split: 0 examples [00:00, ? examples/s]
# /home/gvanerven/code/word2vec-rag-experiment/.env/lib/python3.13/site-packages/datasets/load.py:1429: FutureWarning: The repository for unicamp-dl/quati contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/unicamp-dl/quati
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading data: 0.00B [00:00, ?B/s]
# Generating quati_all_topics split: 0 examples [00:00, ? examples/s]

# %%
quati
# Out:
# DatasetDict({
#     quati_1M_passages: Dataset({
#         features: ['passage_id', 'passage'],
#         num_rows: 1000000
#     })
# })
